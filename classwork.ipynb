# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50])

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# Custom Index

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print(s["a"])
# Out:
# 10

# %% [markdown]
# Series From Dictionary

# %%
data={"Math":90,"Science":80,"English":85}

# %%
print(data)
# Out:
# {'Math': 90, 'Science': 80, 'English': 85}

# %% [markdown]
# DataFrame in Pandas

# %%
data={"Name":["Aman","Ravi","Sita"],"Age":[20,22,19],"City":["Delhi","Mumbai","Bangalore"]}

# %%
print(data)
# Out:
# {'Name': ['Aman', 'Ravi', 'Sita'], 'Age': [20, 22, 19], 'City': ['Delhi', 'Mumbai', 'Bangalore']}

# %%
type(data)
# Out:
# dict

# %%
marks=pd.DataFrame(data)

# %%
print(marks)
# Out:
#    Name  Age       City
# 0  Aman   20      Delhi
# 1  Ravi   22     Mumbai
# 2  Sita   19  Bangalore

# %%
marks=pd.DataFrame(data,index=['Student1','Student2','Student3'])

# %%
print(marks)
# Out:
#           Name  Age       City
# Student1  Aman   20      Delhi
# Student2  Ravi   22     Mumbai
# Student3  Sita   19  Bangalore

# %%
marks.set_index('Name',inplace=True) # Set 'Name' column as index and modify the DataFrame in place

# %%
print(marks)
# Out:
#       Age       City
# Name
# Aman   20      Delhi
# Ravi   22     Mumbai
# Sita   19  Bangalore

# %%
df=pd.DataFrame({"Name":["Aman","Karan","Sita"],"Age":[20,22,19],"Marks":["80","85","90"]})

# %%
df
# Out:
#     Name  Age Marks
# 0   Aman   20    80
# 1  Karan   22    85
# 2   Sita   19    90

# %%
df.head(2)
# Out:
#     Name  Age Marks
# 0   Aman   20    80
# 1  Karan   22    85

# %%
df.tail(2)
# Out:
#     Name  Age Marks
# 1  Karan   22    85
# 2   Sita   19    90

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Age     3 non-null      int64
#  2   Marks   3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   20.333333
# std     1.527525
# min    19.000000
# 25%    19.500000
# 50%    20.000000
# 75%    21.000000
# max    22.000000

# %% [markdown]
# Selecting the Data

# %%
df["Name"]
# Out:
# 0     Aman
# 1    Karan
# 2     Sita
# Name: Name, dtype: str

# %%
df[["Name","Marks"]]
# Out:
#     Name Marks
# 0   Aman    80
# 1  Karan    85
# 2   Sita    90

# %% [markdown]
# Filtering in Pandas

# %%
df["Marks"] = pd.to_numeric(df["Marks"], errors="coerce")
df[df["Marks"]>80]
# Out:
#     Name  Age  Marks
# 1  Karan   22     85
# 2   Sita   19     90

# %%
#Multple Condition
df["Marks"] = pd.to_numeric(df["Marks"], errors="coerce")
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df[(df["Age"]>21) & (df["Marks"]>80)]
# Out:
#     Name  Age  Marks
# 1  Karan   22     85

# %% [markdown]
# Sorting +Value Counts

# %%
df.sort_values("Marks")
# Out:
#     Name  Age  Marks
# 0   Aman   20     80
# 1  Karan   22     85
# 2   Sita   19     90

# %%
df.sort_values("Marks",ascending=False)
# Out:
#     Name  Age  Marks
# 2   Sita   19     90
# 1  Karan   22     85
# 0   Aman   20     80

# %%
df["Age"].value_counts()
# Out:
# Age
# 20    1
# 22    1
# 19    1
# Name: count, dtype: int64
